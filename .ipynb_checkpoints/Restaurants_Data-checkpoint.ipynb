# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from config import Password
import numpy as np

# %%
restaurant_csv=pd.read_csv("./data/Datafiniti_Fast_Food_Restaurants.csv")
obesity_csv=pd.read_csv("./data/National-Obesity-Monitor-Data.csv")
restaurant_csv.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 1  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 2  AVwcopQoByjofQCxgfVa  2016-03-29T05:06:36Z  2018-06-26T02:59:52Z
# 3  AVweXN5RByjofQCxxilK  2017-01-03T07:46:11Z  2018-06-26T02:59:51Z
# 4  AWQ6MUvo3-Khe5l_j3SG  2018-06-26T02:59:43Z  2018-06-26T02:59:43Z
#
#                 address                                    categories  \
# 0      800 N Canal Blvd  American Restaurant and Fast Food Restaurant
# 1      800 N Canal Blvd                         Fast Food Restaurants
# 2   206 Wears Valley Rd                          Fast Food Restaurant
# 3          3652 Parkway                                     Fast Food
# 4  2118 Mt Zion Parkway                          Fast Food Restaurant
#
#            city country                                           keys  \
# 0     Thibodaux      US       us/la/thibodaux/800ncanalblvd/1780593795
# 1     Thibodaux      US       us/la/thibodaux/800ncanalblvd/1780593795
# 2  Pigeon Forge      US  us/tn/pigeonforge/206wearsvalleyrd/-864103396
# 3  Pigeon Forge      US         us/tn/pigeonforge/3652parkway/93075755
# 4        Morrow      US      us/ga/morrow/2118mtzionparkway/1305117222
#
#     latitude  longitude            name postalCode province  \
# 0  29.814697 -90.814742  SONIC Drive In      70301       LA
# 1  29.814697 -90.814742  SONIC Drive In      70301       LA
# 2  35.803788 -83.580553       Taco Bell      37863       TN
# 3  35.782339 -83.551408          Arby's      37863       TN
# 4  33.562738 -84.321143  Steak 'n Shake      30260       GA
#
#                                           sourceURLs  \
# 0  https://foursquare.com/v/sonic-drive-in/4b7361...
# 1  https://foursquare.com/v/sonic-drive-in/4b7361...
# 2  https://www.yellowpages.com/pigeon-forge-tn/mi...
# 3  http://www.yellowbook.com/profile/arbys_163389...
# 4  https://foursquare.com/v/steak-n-shake/4bcf77a...
#
#                                             websites
# 0  https://locations.sonicdrivein.com/la/thibodau...
# 1  https://locations.sonicdrivein.com/la/thibodau...
# 2  http://www.tacobell.com,https://locations.taco...
# 3  http://www.arbys.com,https://locations.arbys.c...
# 4  http://www.steaknshake.com/locations/23851-ste...

# %%
obesity_csv
# Out:
#       group demographic_category demographic  2001-2002  2003-2004  2005-2006  \
# 0    Adults                  Sex       Women       33.2     33.200      35.30
# 1    Adults                  Sex         Men       27.7     31.100      33.30
# 2     Youth                  Sex       Girls       14.3     16.000      14.90
# 3     Youth                  Sex        Boys       16.4     18.200      15.90
# 4  Average                   NaN         NaN       22.9     24.625      24.85
#
#    2007-2008  2009-2010  2011-2012  2013-2014  2015-2016  2017-2018
# 0       35.4     35.800     36.100     40.400     41.100      41.90
# 1       32.2     35.500     33.500     35.000     37.900      43.00
# 2       15.9     15.000     17.200     17.100     17.800      17.80
# 3       17.7     18.600     16.700     17.200     19.100      19.10
# 4       25.3     26.225     25.875     27.425     28.975      30.45

# %%
obesity2_df = pd.DataFrame(obesity_csv.iloc[4]).transpose().copy()
obesity2_df.drop(columns=["demographic_category", "demographic"])
# Out:
#       group 2001-2002 2003-2004 2005-2006 2007-2008 2009-2010 2011-2012  \
# 4  Average       22.9    24.625     24.85      25.3    26.225    25.875
#
#   2013-2014 2015-2016 2017-2018
# 4    27.425    28.975     30.45

# %%
restaurant_df=restaurant_csv[["latitude","longitude","name","province", "address"]]
restaurant_df
# Out:
#        latitude  longitude            name province               address
# 0     29.814697 -90.814742  SONIC Drive In       LA      800 N Canal Blvd
# 1     29.814697 -90.814742  SONIC Drive In       LA      800 N Canal Blvd
# 2     35.803788 -83.580553       Taco Bell       TN   206 Wears Valley Rd
# 3     35.782339 -83.551408          Arby's       TN          3652 Parkway
# 4     33.562738 -84.321143  Steak 'n Shake       GA  2118 Mt Zion Parkway
# ...         ...        ...             ...      ...                   ...
# 9995  36.117563 -80.316553       Pizza Hut       NC     3460 Robinhood Rd
# 9996  36.077718 -80.176748       Pizza Hut       NC  3069 Kernersville Rd
# 9997  36.111015 -80.089165       Pizza Hut       NC         838 S Main St
# 9998  35.719981 -77.945795       Pizza Hut       NC   1702 Glendale Dr SW
# 9999  34.632778 -78.624615       Pizza Hut       NC       1405 W Broad St
#
# [10000 rows x 5 columns]

# %%
# connection_string = "postgres:postgres@localhost:5432/customer_db"
# engine = create_engine(f'postgresql://{connection_string}')


engine = create_engine(f'postgresql://postgres:{Password}@localhost/Restaurants')
conn = engine.connect()

# %%
restaurant_df.to_sql("restaurant",con=engine, if_exists="replace", index=False)

# %%
pd.read_sql("SELECT * FROM restaurant", engine)
# Out:
#        latitude  longitude            name province               address
# 0     29.814697 -90.814742  SONIC Drive In       LA      800 N Canal Blvd
# 1     29.814697 -90.814742  SONIC Drive In       LA      800 N Canal Blvd
# 2     35.803788 -83.580553       Taco Bell       TN   206 Wears Valley Rd
# 3     35.782339 -83.551408          Arby's       TN          3652 Parkway
# 4     33.562738 -84.321143  Steak 'n Shake       GA  2118 Mt Zion Parkway
# ...         ...        ...             ...      ...                   ...
# 9995  36.117563 -80.316553       Pizza Hut       NC     3460 Robinhood Rd
# 9996  36.077718 -80.176748       Pizza Hut       NC  3069 Kernersville Rd
# 9997  36.111015 -80.089165       Pizza Hut       NC         838 S Main St
# 9998  35.719981 -77.945795       Pizza Hut       NC   1702 Glendale Dr SW
# 9999  34.632778 -78.624615       Pizza Hut       NC       1405 W Broad St
#
# [10000 rows x 5 columns]

# %%
#Create engine for Obesity table

obesity2_df.to_sql("obesity",con=engine, if_exists="replace", index=False)

# %%
pd.read_sql("SELECT * FROM obesity", engine)
# Out:
#       group demographic_category demographic  2001-2002  2003-2004  2005-2006  \
# 0  Average                  None        None       22.9     24.625      24.85
#
#    2007-2008  2009-2010  2011-2012  2013-2014  2015-2016  2017-2018
# 0       25.3     26.225     25.875     27.425     28.975      30.45

# %%
import csv
import json
import pandas as pd
import sys, getopt, pprint
from pymongo import MongoClient 
from bson.json_util import dumps, loads 
client = MongoClient('localhost', 27017)
db = client["Chipotle"]
col = db["restaurants"]
with open('./data/Datafiniti_Fast_Food_Restaurants.csv', 'r') as read_obj:
    # pass the file object to reader() to get the reader object
    csv_reader = csv.DictReader(read_obj)
    # Pass reader object to list() to get a list of lists
    mylist = list(csv_reader)
    #print(list_of_rows)
    x = col.insert_many(mylist)

    #print list of the _id values of the inserted documents:
    print(x.inserted_ids)
# Out:
# [ObjectId('604d14bc0a8c1e434faafab1'), ObjectId('604d14bc0a8c1e434faafab2'), ObjectId('604d14bc0a8c1e434faafab3'), ObjectId('604d14bc0a8c1e434faafab4'), ObjectId('604d14bc0a8c1e434faafab5'), ObjectId('604d14bc0a8c1e434faafab6'), ObjectId('604d14bc0a8c1e434faafab7'), ObjectId('604d14bc0a8c1e434faafab8'), ObjectId('604d14bc0a8c1e434faafab9'), ObjectId('604d14bc0a8c1e434faafaba'), ObjectId('604d14bc0a8c1e434faafabb'), ObjectId('604d14bc0a8c1e434faafabc'), ObjectId('604d14bc0a8c1e434faafabd'), ObjectId('604d14bc0a8c1e434faafabe'), ObjectId('604d14bc0a8c1e434faafabf'), ObjectId('604d14bc0a8c1e434faafac0'), ObjectId('604d14bc0a8c1e434faafac1'), ObjectId('604d14bc0a8c1e434faafac2'), ObjectId('604d14bc0a8c1e434faafac3'), ObjectId('604d14bc0a8c1e434faafac4'), ObjectId('604d14bc0a8c1e434faafac5'), ObjectId('604d14bc0a8c1e434faafac6'), ObjectId('604d14bc0a8c1e434faafac7'), ObjectId('604d14bc0a8c1e434faafac8'), ObjectId('604d14bc0a8c1e434faafac9'), ObjectId('604d14bc0a8c1e434faafaca'), ObjectId('604d14bc0a8c1e434faafacb'), ObjectId('604d14bc0a8c1e434faafacc'), ObjectId('604d14bc0a8c1e434faafacd'), ObjectId('604d14bc0a8c1e434faaface'), ObjectId('604d14bc0a8c1e434faafacf'), ObjectId('604d14bc0a8c1e434faafad0'), ObjectId('604d14bc0a8c1e434faafad1'), ObjectId('604d14bc0a8c1e434faafad2'), ObjectId('604d14bc0a8c1e434faafad3'), ObjectId('604d14bc0a8c1e434faafad4'), ObjectId('604d14bc0a8c1e434faafad5'), ObjectId('604d14bc0a8c1e434faafad6'), ObjectId('604d14bc0a8c1e434faafad7'), ObjectId('604d14bc0a8c1e434faafad8'), ObjectId('604d14bc0a8c1e434faafad9'), ObjectId('604d14bc0a8c1e434faafada'), ObjectId('604d14bc0a8c1e434faafadb'), ObjectId('604d14bc0a8c1e434faafadc'), ObjectId('604d14bc0a8c1e434faafadd'), ObjectId('604d14bc0a8c1e434faafade'), ObjectId('604d14bc0a8c1e434faafadf'), ObjectId('604d14bc0a8c1e434faafae0'), ObjectId('604d14bc0a8c1e434faafae1'), ObjectId('604d14bc0a8c1e434faafae2'), ObjectId('604d14bc0a8c1e434faafae3'), ObjectId('604d14bc0a8c1e434faafae4'), ObjectId('604d14bc0a8c1e434faafae5'), ObjectId('604d14bc0a8c1e434faafae6'), ObjectId('604d14bc0a8c1e434faafae7'), ObjectId('604d14bc0a8c1e434faafae8'), ObjectId('604d14bc0a8c1e434faafae9'), ObjectId('604d14bc0a8c1e434faafaea'), ObjectId('604d14bc0a8c1e434faafaeb'), ObjectId('604d14bc0a8c1e434faafaec'), ObjectId('604d14bc0a8c1e434faafaed'), ObjectId('604d14bc0a8c1e434faafaee'), ObjectId('604d14bc0a8c1e434faafaef'), ObjectId('604d14bc0a8c1e434faafaf0'), ObjectId('604d14bc0a8c1e434faafaf1'), ObjectId('604d14bc0a8c1e434faafaf2'), ObjectId('604d14bc0a8c1e434faafaf3'), ObjectId('604d14bc0a8c1e434faafaf4'), ObjectId('604d14bc0a8c1e434faafaf5'), ObjectId('604d14bc0a8c1e434faafaf6'), ObjectId('604d14bc0a8c1e434faafaf7'), ObjectId('604d14bc0a8c1e434faafaf8'), ObjectId('604d14bc0a8c1e434faafaf9'), ObjectId('604d14bc0a8c1e434faafafa'), ObjectId('604d14bc0a8c1e434faafafb'), ObjectId('604d14bc0a8c1e434faafafc'), ObjectId('604d14bc0a8c1e434faafafd'), ObjectId('604d14bc0a8c1e434faafafe'), ObjectId('604d14bc0a8c1e434faafaff'), ObjectId('604d14bc0a8c1e434faafb00'), ObjectId('604d14bc0a8c1e434faafb01'), ObjectId('604d14bc0a8c1e434faafb02'), ObjectId('604d14bc0a8c1e434faafb03'), ObjectId('604d14bc0a8c1e434faafb04'), ObjectId('604d14bc0a8c1e434faafb05'), ObjectId('604d14bc0a8c1e434faafb06'), ObjectId('604d14bc0a8c1e434faafb07'), ObjectId('604d14bc0a8c1e434faafb08'), ObjectId('604d14bc0a8c1e434faafb09'), ObjectId('604d14bc0a8c1e434faafb0a'), ObjectId('604d14bc0a8c1e434faafb0b'), ObjectId('604d14bc0a8c1e434faafb0c'), ObjectId('604d14bc0a8c1e434faafb0d'), ObjectId('604d14bc0a8c1e434faafb0e'), ObjectId('604d14bc0a8c1e434faafb0f'), ObjectId('604d14bc0a8c1e434faafb10'), ObjectId('604d14bc0a8c1e434faafb11'), ObjectId('604d14bc0a8c1e434faafb12'), ObjectId('604d14bc0a8c1e434faafb13'), ObjectId('604d14bc0a8c1e434faafb14'), ObjectId('604d14bc0a8c1e434faafb15'), ObjectId('604d14bc0a8c1e434faafb16'), ObjectId('604d14bc0a8c1e434faafb17'), ObjectId('604d14bc0a8c1e434faafb18'), ObjectId('604d14bc0a8c1e434faafb19'), ObjectId( ...

# %%
from pymongo import MongoClient 
from bson.json_util import dumps, loads 
client = MongoClient('localhost', 27017) 
  
db = client["Chipotle"]
col = db["restaurants"] 
  
# Now creating a Cursor instance 
# using find() function 
cursor = col.find() 
  
# Converting cursor to the list  
# of dictionaries 
list_cur = list(cursor) 
  
# Converting to the JSON 
json_data = dumps(list_cur, indent = 2)  
   
# Writing data to file data.json 
with open('restaurant_locations.json', 'w') as file: 
    file.write(json_data)
