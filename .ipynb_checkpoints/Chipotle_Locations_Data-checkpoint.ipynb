# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

import numpy as np

# %%
# pd.read_json("https://www.kaggle.com/jeffreybraun/chipotle-locations?select=us-states.json")
chipotle_csv=pd.read_csv("./data/chipotle_stores.csv")
chipotle_csv.head()
# Out:
#      state    location                                    address   latitude  \
# 0  Alabama      Auburn     346 W Magnolia Ave Auburn, AL 36832 US  32.606813
# 1  Alabama  Birmingham      300 20th St S Birmingham, AL 35233 US  33.509721
# 2  Alabama  Birmingham     3220 Morrow Rd Birmingham, AL 35235 US  33.595581
# 3  Alabama  Birmingham   4719 Highway 280 Birmingham, AL 35242 US  33.422582
# 4  Alabama     Cullman  1821 Cherokee Ave SW Cullman, AL 35055 US  34.154134
#
#    longitude
# 0 -85.487328
# 1 -86.802756
# 2 -86.647437
# 3 -86.698279
# 4 -86.841220

# %%
# engine = create_engine(f'postgresql://postgres:{Password}@localhost/Restaurants')
# conn = engine.connect()

# %%
# chipotle_csv.to_sql("chipotle",con=engine, if_exists="replace", index=False)

# %%
# pd.read_sql("SELECT * FROM chipotle", engine)

# %%
import csv
import json
import pandas as pd
import sys, getopt, pprint
from pymongo import MongoClient 
from bson.json_util import dumps, loads 
client = MongoClient('localhost', 27017)
db = client["Chipotle"]
col = db["chipotle_locations"]
with open('./data/chipotle_stores.csv', 'r') as read_obj:
    # pass the file object to reader() to get the reader object
    csv_reader = csv.DictReader(read_obj)
    # Pass reader object to list() to get a list of lists
    mylist = list(csv_reader)
    #print(list_of_rows)
    x = col.insert_many(mylist)

    #print list of the _id values of the inserted documents:
    print(x.inserted_ids)
# Out:
# [ObjectId('60500654dea659865de3249a'), ObjectId('60500654dea659865de3249b'), ObjectId('60500654dea659865de3249c'), ObjectId('60500654dea659865de3249d'), ObjectId('60500654dea659865de3249e'), ObjectId('60500654dea659865de3249f'), ObjectId('60500654dea659865de324a0'), ObjectId('60500654dea659865de324a1'), ObjectId('60500654dea659865de324a2'), ObjectId('60500654dea659865de324a3'), ObjectId('60500654dea659865de324a4'), ObjectId('60500654dea659865de324a5'), ObjectId('60500654dea659865de324a6'), ObjectId('60500654dea659865de324a7'), ObjectId('60500654dea659865de324a8'), ObjectId('60500654dea659865de324a9'), ObjectId('60500654dea659865de324aa'), ObjectId('60500654dea659865de324ab'), ObjectId('60500654dea659865de324ac'), ObjectId('60500654dea659865de324ad'), ObjectId('60500654dea659865de324ae'), ObjectId('60500654dea659865de324af'), ObjectId('60500654dea659865de324b0'), ObjectId('60500654dea659865de324b1'), ObjectId('60500654dea659865de324b2'), ObjectId('60500654dea659865de324b3'), ObjectId(
# ...

# %%
from pymongo import MongoClient 
from bson.json_util import dumps, loads 
client = MongoClient('localhost', 27017) 
  
db = client["Chipotle"]
col = db["chipotle_locations"] 
  
# Now creating a Cursor instance 
# using find() function 
cursor = col.find() 
  
# Converting cursor to the list  
# of dictionaries 
list_cur = list(cursor) 
  
# Converting to the JSON 
json_data = dumps(list_cur, indent = 2)  
   
# Writing data to file data.json 
with open('chipotle_locations.json', 'w') as file: 
    file.write(json_data)
